# %%
import pandas as pd

# %%
msg_dtl = pd.read_csv('./raw/11월_친구톡utm.csv')
msg_dtl['발송시간'] = pd.to_datetime(msg_dtl['발송시간'])
msg_dtl.head(2)
# Out:
# C:\Users\amore\AppData\Local\Temp\ipykernel_7624\249323394.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   msg_dtl['발송시간'] = pd.to_datetime(msg_dtl['발송시간'])
#             저니                               저니명  버전 발송타입                발송시간  \
# 0  IN24112601S  IN24112601S_이니_광고정보수집안내_241126수기   1  알림톡 2024-11-27 17:06:00
# 1  IN24111901S    IN24111901S_이니스프리_가입즉시 알림톡_테스트   7  알림톡 2024-11-22 10:03:00
#
#                                                   본문  \
# 0  [안내] 이니스프리\n광고성정보 수신동의 여부 안내\n\n고객님, 이니스프리를 이용...
# 1  [안내] 이니스프리 개인정보 이용내역 안내\n\n최소정님, 이니스프리를 이용해주셔서...
#
#                                                   버튼
# 0         {"button":[{"name":"채널 추가", "type":"AC"}]}
# 1  {"button":[{"name":"개인정보 이용내역 상세보기", "type":"W...

# %%
jour_set = msg_dtl['저니'].unique()
len(jour_set)
# Out:
# 518

# %%
long_text = ''
for j in jour_set:
    long_text += f"OR JOUR_NM LIKE '%{j}%' "

long_text
# Out:
# "OR JOUR_NM LIKE '%IN24112601S%' OR JOUR_NM LIKE '%IN24111901S%' OR JOUR_NM LIKE '%IN24011902A%' OR JOUR_NM LIKE '%IN24060402S%' OR JOUR_NM LIKE '%IN24061107S%' OR JOUR_NM LIKE '%IN24062011S%' OR JOUR_NM LIKE '%IN24062001S%' OR JOUR_NM LIKE '%IN24062004S%' OR JOUR_NM LIKE '%IN24062503S%' OR JOUR_NM LIKE '%IN24062404S%' OR JOUR_NM LIKE '%IN24062402S%' OR JOUR_NM LIKE '%IN24070409S%' OR JOUR_NM LIKE '%IN24071034S%' OR JOUR_NM LIKE '%IN24071033S%' OR JOUR_NM LIKE '%IN24071017S%' OR JOUR_NM LIKE '%IN24071009S%' OR JOUR_NM LIKE '%IN24071023S%' OR JOUR_NM LIKE '%IN24071018S%' OR JOUR_NM LIKE '%IN24071809S%' OR JOUR_NM LIKE '%IN24071804S%' OR JOUR_NM LIKE '%IN24072405S%' OR JOUR_NM LIKE '%IN24080207S%' OR JOUR_NM LIKE '%IN24080206S%' OR JOUR_NM LIKE '%IN24080208S%' OR JOUR_NM LIKE '%IN24020601A%' OR JOUR_NM LIKE '%IN24082009S%' OR JOUR_NM LIKE '%IN24082018S%' OR JOUR_NM LIKE '%IN24082208S%' OR JOUR_NM LIKE '%IN24082205S%' OR JOUR_NM LIKE '%IN24082716S%' OR JOUR_NM LIKE '%IN24090404S%' OR JO
# ...

# %%
# 위 저니에 포함되는 메시지들만 추출해서 다시 데이터 셋 만들기!!!!
