# %%
import pandas as pd

# %%
df = pd.read_csv('./data/final.csv', index_col=0)
df.head(2)
# Out:
#    y  msg_length  max_discount  emoji_count  personalized  time_pressure  \
# 0  0          30          32.0            0             0              0
# 1  0          41           0.0            0             0              0
#
#    SRCH_EFRT  PRDV_CNT  CAT_CNT  SAMGE_PAGE_CNT  ...  AVG_DEPTH  day_off  \
# 0          6         2        0               2  ...  24.285714        1
# 1         15         4        0               4  ...  16.666667        0
#
#    SEX_CD  AVG_SAL_AMT  AGE_30  AGE_50  AGE_60  AGE_1020  WEEKDAY  WEEKEND
# 0       1      21490.0       0       0       0         0        4        0
# 1       1      26085.0       0       1       0         0        6        1
#
# [2 rows x 21 columns]

# %%
df_origin = df[['y', 'msg_length', 'max_discount', 'personalized', 'time_pressure', 'AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT',
       'AVG_DEPTH', 'day_off', 'WEEKEND']]

# %% [markdown]
# ### 각 변수 EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family="Malgun Gothic")

import warnings 
warnings.filterwarnings("ignore")


for col in df_origin.columns:
    print('='*50)
    print(f"변수명: {col}")
    print("데이터 유형:", df_origin[col].dtype)

    # 변수에 대한 기초 통계량 출력
    print("기초 통계량:")
    print(df_origin[col].describe())

    if df_origin[col].dtype == 'object' or df_origin[col].nunique() < 10:
        temp = pd.DataFrame(df_origin[col].value_counts()).reset_index()
        print("빈도 분포:")
        print(df_origin[col].value_counts())
        # 막대그래프 그리기
        sns.barplot(x = col,
                    y = 'count',
                    data = temp)
        plt.title(f"{col} 분포(막대그래프)")
        plt.xlabel(col)
        plt.ylabel("빈도수")
        plt.show()
    else:
        # 수치형 변수의 경우 히스토그램과 박스플롯을 통해 분포 및 이상치 확인
        plt.figure(figsize=(12,4))
        plt.subplot(1,2,1)
        df_origin[col].hist(bins=20)
        plt.title(f"{col} 히스토그램")
        plt.xlabel(col)
        plt.ylabel("빈도수")

        plt.subplot(1,2,2)
        df_origin.boxplot(column=col)
        plt.title(f"{col} 박스플롯")

        plt.tight_layout()
        plt.show()
# Out:
# ==================================================
# 변수명: y
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     3.044075e-02
# std      1.717968e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: y, dtype: float64
# 빈도 분포:
# y
# 0    1016133
# 1      31903
# Name: count, dtype: int64
# ==================================================
# 변수명: msg_length
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     1.007307e+02
# std      9.475957e+01
# min      1.700000e+01
# 25%      3.000000e+01
# 50%      4.500000e+01
# 75%      1.770000e+02
# max      3.290000e+02
# Name: msg_length, dtype: float64
# ==================================================
# 변수명: max_discount
# 데이터 유형: float64
# 기초 통계량:
# count    1.048036e+06
# mean     3.318570e+01
# std      2.105396e+01
# min      0.000000e+00
# 25%      2.800000e+01
# 50%      3.333333e+01
# 75%      5.000000e+01
# max      1.000000e+02
# Name: max_discount, dtype: float64
# ==================================================
# 변수명: personalized
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     1.743146e-01
# std      3.793800e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: personalized, dtype: float64
# 빈도 분포:
# personalized
# 0    865348
# 1    182688
# Name: count, dtype: int64
# ==================================================
# 변수명: time_pressure
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     3.266777e-02
# std      1.777656e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: time_pressure, dtype: float64
# 빈도 분포:
# time_pressure
# 0    1013799
# 1      34237
# Name: count, dtype: int64
# ==================================================
# 변수명: AVG_SAL_AMT
# 데이터 유형: float64
# 기초 통계량:
# count    1.048036e+06
# mean     1.468416e+04
# std      9.174287e+03
# min      0.000000e+00
# 25%      8.401250e+03
# 50%      1.421042e+04
# 75%      1.955167e+04
# max      2.635000e+05
# Name: AVG_SAL_AMT, dtype: float64
# ==================================================
# 변수명: SRCH_EFRT
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     1.654643e+01
# std      2.043042e+01
# min      4.000000e+00
# 25%      5.000000e+00
# 50%      9.000000e+00
# 75%      1.900000e+01
# max      4.840000e+02
# Name: SRCH_EFRT, dtype: float64
# ==================================================
# 변수명: CAT_CNT
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     5.489802e-01
# std      8.325031e-01
# min     -1.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      8.000000e+00
# Name: CAT_CNT, dtype: float64
# ==================================================
# 변수명: AVG_DEPTH
# 데이터 유형: float64
# 기초 통계량:
# count    1.048036e+06
# mean     2.615958e+01
# std      1.574562e+01
# min      1.000000e+01
# 25%      1.000000e+01
# 50%      2.166667e+01
# 75%      4.200000e+01
# max      1.000000e+02
# Name: AVG_DEPTH, dtype: float64
# ==================================================
# 변수명: day_off
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     5.677734e-01
# std      4.953857e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: day_off, dtype: float64
# 빈도 분포:
# day_off
# 1    595047
# 0    452989
# Name: count, dtype: int64
# ==================================================
# 변수명: WEEKEND
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     2.651188e-01
# std      4.413966e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: WEEKEND, dtype: float64
# 빈도 분포:
# WEEKEND
# 0    770182
# 1    277854
# Name: count, dtype: int64

# %%
def remove_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = 0
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# %%
import statsmodels.api as sm

df_remove = df_origin[df_origin['max_discount'] < 34]
df_remove = remove_outliers(df_remove, ["AVG_SAL_AMT", "SRCH_EFRT", "CAT_CNT", "AVG_DEPTH"])

# 특징 변수와 종속 변수 분리
X = df_remove.drop(columns=['y'])  
y = df_remove['y']

# 상수항 추가
X = sm.add_constant(X)

# 로지스틱 회귀 모델 생성 및 학습
model = sm.Logit(y, X)
result = model.fit()

result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.151690
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               437606
# Model:                          Logit   Df Residuals:                   437595
# Method:                           MLE   Df Model:                           10
# Date:                Fri, 28 Mar 2025   Pseudo R-squ.:                 0.07270
# Time:                        14:58:18   Log-Likelihood:                -66380.
# converged:                       True   LL-Null:                       -71585.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -3.7734      0.032   -119.777      0.000      -3.835      -3.712
# msg_length        0.0072      0.000     47.861      0.000       0.007       0.008
# max_discount      0.0053      0.001      8.023      0.000       0.004       0.007
# personalized     -1.1759      0.185     -6.372      0.000      -1.538      -0.814
# time_pressure     1.9011      0.033     56.837      0.000       1.836       1.967
# AVG_SAL_AMT    6.444e-06   1.01e-06      6.372      0.000    4.46e-06    8.43e-06
# SRCH_EFRT         0.0065      0.001      5.422      0.000       0.004       0.009
# CAT_CNT          -0.0436      0.015     -2.840      0.005      -0.074      -0.013
# AVG_DEPTH      2.107e-05      0.001      0.038      0.970      -0.001       0.001
# day_off          -0.0401      0.016     -2.470      0.014      -0.072      -0.008
# WEEKEND          -1.9624      0.035    -56.447      0.000      -2.031      -1.894
# =================================================================================
# """

# %% [markdown]
# ### 교호작용항 추가

# %%
df_control = df[['y', 'msg_length', 'max_discount', 'personalized', 'time_pressure', 'AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT',
       'AVG_DEPTH', 'day_off', 'WEEKEND']]


df_control = remove_outliers(df_control, ["AVG_SAL_AMT", "SRCH_EFRT", "CAT_CNT", "AVG_DEPTH"])

dl = ['msg_length', 'max_discount', 'personalized', 'time_pressure']
ml = ['AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT', 'AVG_DEPTH', 'day_off', 'WEEKEND']

df_m = df_control.copy()

for d in dl:
    for m in ml:
       interaction_term = f"{d}_x_{m}"  # 교호작용항 이름 설정
       df_m[interaction_term] = df_m[d] * df_m[m]  # 교호작용항 계산

interaction_term = ['y', 'msg_length', 'max_discount', 'personalized', 'time_pressure', 'AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT',
       'AVG_DEPTH', 'day_off', 'WEEKEND',
       'msg_length_x_SRCH_EFRT', 'msg_length_x_CAT_CNT', 'msg_length_x_AVG_DEPTH', 'max_discount_x_AVG_SAL_AMT', 
       'personalized_x_AVG_SAL_AMT', 'time_pressure_x_SRCH_EFRT', 'time_pressure_x_CAT_CNT', 'time_pressure_x_day_off', 'time_pressure_x_WEEKEND']

df_m = df_m[interaction_term]
df_m.head(2)
# Out:
#    y  msg_length  max_discount  personalized  time_pressure  AVG_SAL_AMT  \
# 0  0          30          32.0             0              0      21490.0
# 1  0          41           0.0             0              0      26085.0
#
#    SRCH_EFRT  CAT_CNT  AVG_DEPTH  day_off  WEEKEND  msg_length_x_SRCH_EFRT  \
# 0          6        0  24.285714        1        0                     180
# 1         15        0  16.666667        0        1                     615
#
#    msg_length_x_CAT_CNT  msg_length_x_AVG_DEPTH  max_discount_x_AVG_SAL_AMT  \
# 0                     0              728.571429                    687680.0
# 1                     0              683.333333                         0.0
#
#    personalized_x_AVG_SAL_AMT  time_pressure_x_SRCH_EFRT  \
# 0                         0.0                          0
# 1                         0.0                          0
#
#    time_pressure_x_CAT_CNT  time_pressure_x_day_off  time_pressure_x_WEEKEND
# 0                        0                        0                        0
# 1                        0                        0                        0

# %%
# 특징 변수와 종속 변수 분리
X = df_m.drop(columns=['y'])  
y = df_m['y']

# 상수항 추가
X = sm.add_constant(X)

# 로지스틱 회귀 모델 생성 및 학습
model = sm.Logit(y, X)
result = model.fit()

result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.129568
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               878321
# Model:                          Logit   Df Residuals:                   878301
# Method:                           MLE   Df Model:                           19
# Date:                Fri, 28 Mar 2025   Pseudo R-squ.:                 0.04505
# Time:                        14:59:17   Log-Likelihood:            -1.1380e+05
# converged:                      False   LL-Null:                   -1.1917e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.1416      0.029   -107.022      0.000      -3.199      -3.084
# msg_length                     0.0026      0.000     16.135      0.000       0.002       0.003
# max_discount                  -0.0190      0.001    -29.476      0.000      -0.020      -0.018
# personalized                   0.3667      0.045      8.194      0.000       0.279       0.454
# time_pressure                  1.1846      0.052     22.721      0.000       1.082       1.287
# AVG_SAL_AMT                 6.563e-06   1.25e-06      5.242      0.000    4.11e-06    9.02e-06
# SRCH_EFRT                      0.0111      0.001      7.830      0.000       0.008       0.014
# CAT_CNT                       -0.1024      0.020     -5.238      0.000      -0.141      -0.064
# AVG_DEPTH                      0.0016      0.001      2.419      0.016       0.000       0.003
# day_off                       -0.0165      0.013     -1.242      0.214      -0.042       0.010
# WEEKEND                       -0.8667      0.019    -45.799      0.000      -0.904      -0.830
# msg_length_x_SRCH_EFRT        -0.0001   9.44e-06    -12.805      0.000      -0.000      -0.000
# msg_length_x_CAT_CNT           0.0011      0.000      8.728      0.000       0.001       0.001
# msg_length_x_AVG_DEPTH     -5.177e-06   4.45e-06     -1.163      0.245   -1.39e-05    3.55e-06
# max_discount_x_AVG_SAL_AMT -1.665e-07   4.15e-08     -4.013      0.000   -2.48e-07   -8.52e-08
# personalized_x_AVG_SAL_AMT -8.275e-06   2.37e-06     -3.498      0.000   -1.29e-05   -3.64e-06
# time_pressure_x_SRCH_EFRT     -0.0052      0.003     -1.584      0.113      -0.012       0.001
# time_pressure_x_CAT_CNT       -0.0577      0.047     -1.233      0.218      -0.149       0.034
# time_pressure_x_day_off        0.0902      0.049      1.830      0.067      -0.006       0.187
# time_pressure_x_WEEKEND      -17.4294    299.118     -0.058      0.954    -603.690     568.831
# ==============================================================================================
# """

# %% [markdown]
# ### 모델 평가

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

logit = LogisticRegression()
logit.fit(X,y)
X.head(2)
# Out:
#    const  msg_length  max_discount  personalized  time_pressure  AVG_SAL_AMT  \
# 0    1.0          30          32.0             0              0      21490.0
# 1    1.0          41           0.0             0              0      26085.0
#
#    SRCH_EFRT  CAT_CNT  AVG_DEPTH  day_off  WEEKEND  msg_length_x_SRCH_EFRT  \
# 0          6        0  24.285714        1        0                     180
# 1         15        0  16.666667        0        1                     615
#
#    msg_length_x_CAT_CNT  msg_length_x_AVG_DEPTH  max_discount_x_AVG_SAL_AMT  \
# 0                     0              728.571429                    687680.0
# 1                     0              683.333333                         0.0
#
#    personalized_x_AVG_SAL_AMT  time_pressure_x_SRCH_EFRT  \
# 0                         0.0                          0
# 1                         0.0                          0
#
#    time_pressure_x_CAT_CNT  time_pressure_x_day_off  time_pressure_x_WEEKEND
# 0                        0                        0                        0
# 1                        0                        0                        0

# %%
predict = logit.predict(X)

# 분류모델 평가
print('accuracy score:', accuracy_score(y, predict))
print('f1_score score:', f1_score(y, predict))
print('recall score:', recall_score(y, predict))
print('precision score', precision_score(y, predict))
# Out:
# accuracy score: 0.9693119030513901
# f1_score score: 0.0007414547341884778
# recall score: 0.0003761236694625193
# precision score 0.025839793281653745

# %% [markdown]
# ### 변수 확인

# %%
import numpy as np

# 상관 계수 행렬 계산
corr_matrix = df_m.corr().abs()

# 상관 계수가 높은 변수 찾기
high_corr_var = np.where(corr_matrix > 0.7)
high_corr_var = [(corr_matrix.index[x], corr_matrix.columns[y]) for x, y in zip(*high_corr_var) if x != y and x < y]

# 높은 상관 관계를 갖는 변수 출력
print("상관 관계가 높은 변수들:", high_corr_var)
# Out:
# 상관 관계가 높은 변수들: [('msg_length', 'personalized'), ('msg_length', 'msg_length_x_AVG_DEPTH'), ('msg_length', 'personalized_x_AVG_SAL_AMT'), ('personalized', 'personalized_x_AVG_SAL_AMT'), ('time_pressure', 'time_pressure_x_SRCH_EFRT'), ('time_pressure', 'time_pressure_x_day_off'), ('msg_length_x_SRCH_EFRT', 'msg_length_x_AVG_DEPTH'), ('time_pressure_x_SRCH_EFRT', 'time_pressure_x_CAT_CNT')]

# %%
# 다중공선성
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

df_X = df_control.drop(columns=['y'])

def calculate_vif(df):
    df_const = add_constant(df)
    vif = pd.DataFrame()
    vif["feature"] = df_const.columns
    vif["VIF"] = [variance_inflation_factor(df_const.values, i) for i in range(df_const.shape[1])]
    return vif

vif_df = calculate_vif(df_X)
print(vif_df)
# Out:
#           feature        VIF
# 0           const  13.780533
# 1      msg_length   2.934032
# 2    max_discount   1.072379
# 3    personalized   3.018298
# 4   time_pressure   1.021120
# 5     AVG_SAL_AMT   1.059044
# 6       SRCH_EFRT   1.445419
# 7         CAT_CNT   1.331676
# 8       AVG_DEPTH   1.185464
# 9         day_off   1.014410
# 10        WEEKEND   1.001406

# %%
df_X.corr()
# Out:
#                msg_length  max_discount  personalized  time_pressure  \
# msg_length       1.000000     -0.007724      0.800434      -0.102674
# max_discount    -0.007724      1.000000      0.140215      -0.082772
# personalized     0.800434      0.140215      1.000000      -0.083055
# time_pressure   -0.102674     -0.082772     -0.083055       1.000000
# AVG_SAL_AMT      0.081200      0.045950      0.138851       0.037832
# SRCH_EFRT        0.027298      0.029845      0.058261       0.012487
# CAT_CNT          0.019955      0.031590      0.055048       0.006562
# AVG_DEPTH        0.017135      0.033105      0.065174       0.019583
# day_off          0.000748     -0.013236     -0.024322      -0.008860
# WEEKEND         -0.015382     -0.008534     -0.014938       0.011800
#
#                AVG_SAL_AMT  SRCH_EFRT   CAT_CNT  AVG_DEPTH   day_off   WEEKEND
# msg_length        0.081200   0.027298  0.019955   0.017135  0.000748 -0.015382
# max_discount      0.045950   0.029845  0.031590   0.033105 -0.013236 -0.008534
# personalized      0.138851   0.058261  0.055048   0.065174 -0.024322 -0.014938
# time_pressure     0.037832   0.012487  0.006562   0.019583 -0.008860  0.011800
# AVG_SAL_AMT       1.000000   0.107482  0.138906   0.144342 -0.079280 -0.008351
# SRCH_EFRT         0.107482   1.000000  0.484979   0.374232 -0.049074 -0.014554
# CAT_CNT           0.138906   0.484979  1.000000   0.232864 -0.089372  0.009231
# AVG_DEPTH         0.144342   0.374232  0.232864   1.000000 -0.050290  0.001511
# day_off          -0.079280  -0.049074 -0.089372  -0.050290  1.000000 -0.018349
# WEEKEND          -0.008351  -0.014554  0.009231   0.001511 -0.018349  1.000000

# %% [markdown]
# ## 추가분석

# %% [markdown]
# ### 샘플링 후 분석

# %%
df_0 = df_m[df_m['y'] == 0]
df_1 = df_m[df_m['y'] == 1]

print(df_0.shape)
print(df_1.shape)
# Out:
# (851734, 20)
# (26587, 20)

# %%
df_0 = df_0.sample(n=16907, random_state=21)

df_sample = pd.concat([df_0, df_1], ignore_index=True)

# 특징 변수와 종속 변수 분리
X_sample = df_sample.drop(columns=['y'])  
y_sample = df_sample['y']

# 상수항 추가
X_sample = sm.add_constant(X_sample)

# 로지스틱 회귀 모델 생성 및 학습
model = sm.Logit(y_sample, X_sample)
result = model.fit()

result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.612226
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                43494
# Model:                          Logit   Df Residuals:                    43474
# Method:                           MLE   Df Model:                           19
# Date:                Fri, 28 Mar 2025   Pseudo R-squ.:                 0.08373
# Time:                        15:00:39   Log-Likelihood:                -26628.
# converged:                      False   LL-Null:                       -29061.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.7664      0.052     14.772      0.000       0.665       0.868
# msg_length                     0.0035      0.000     12.578      0.000       0.003       0.004
# max_discount                  -0.0206      0.001    -18.930      0.000      -0.023      -0.018
# personalized                   0.6551      0.079      8.284      0.000       0.500       0.810
# time_pressure                  0.9877      0.127      7.771      0.000       0.739       1.237
# AVG_SAL_AMT                  6.13e-06   2.44e-06      2.509      0.012    1.34e-06    1.09e-05
# SRCH_EFRT                      0.0117      0.002      5.154      0.000       0.007       0.016
# CAT_CNT                       -0.1014      0.030     -3.338      0.001      -0.161      -0.042
# AVG_DEPTH                      0.0011      0.001      1.001      0.317      -0.001       0.003
# day_off                       -0.0173      0.022     -0.801      0.423      -0.060       0.025
# WEEKEND                       -1.0939      0.028    -38.781      0.000      -1.149      -1.039
# msg_length_x_SRCH_EFRT        -0.0001   1.53e-05     -9.120      0.000      -0.000      -0.000
# msg_length_x_CAT_CNT           0.0010      0.000      4.758      0.000       0.001       0.001
# msg_length_x_AVG_DEPTH      3.546e-07   7.64e-06      0.046      0.963   -1.46e-05    1.53e-05
# max_discount_x_AVG_SAL_AMT -1.557e-07   7.07e-08     -2.203      0.028   -2.94e-07   -1.71e-08
# personalized_x_AVG_SAL_AMT -1.558e-05   3.97e-06     -3.928      0.000   -2.33e-05    -7.8e-06
# time_pressure_x_SRCH_EFRT      0.0113      0.008      1.379      0.168      -0.005       0.027
# time_pressure_x_CAT_CNT       -0.2604      0.107     -2.435      0.015      -0.470      -0.051
# time_pressure_x_day_off        0.0212      0.119      0.179      0.858      -0.211       0.254
# time_pressure_x_WEEKEND      -26.6456   3.47e+04     -0.001      0.999    -6.8e+04     6.8e+04
# ==============================================================================================
# """

# %%
logit = LogisticRegression()
logit.fit(X_sample,y_sample)

predict = logit.predict(X)

# 분류모델 평가
print('accuracy score:', accuracy_score(y, predict))
print('f1_score score:', f1_score(y, predict))
print('recall score:', recall_score(y, predict))
print('precision score', precision_score(y, predict))
# Out:
# accuracy score: 0.22481530101181688
# f1_score score: 0.06595613624734031
# recall score: 0.9041636890209501
# precision score 0.03422642777410757
