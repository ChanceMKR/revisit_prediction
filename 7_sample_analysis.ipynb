# %%
import pandas as pd

# %%
sm1 = pd.read_csv('./data/sample1.csv', index_col=0)
print(sm1.shape)
sm1.head(2)
# Out:
# (500000, 21)
#    y  msg_length  max_discount  emoji_count  personalized  time_pressure  \
# 0  0          30          32.0            0             0              0
# 1  0          41           0.0            0             0              0
#
#    SRCH_EFRT  PRDV_CNT  CAT_CNT  SAMGE_PAGE_CNT  ...  AVG_DEPTH  day_off  \
# 0          6         2        0               2  ...  24.285714        1
# 1         15         4        0               4  ...  16.666667        0
#
#    SEX_CD  AVG_SAL_AMT  AGE_30  AGE_50  AGE_60  AGE_1020  WEEKDAY  WEEKEND
# 0       1      21490.0       0       0       0         0        4        0
# 1       1      26085.0       0       1       0         0        6        1
#
# [2 rows x 21 columns]

# %%
sm2 = pd.read_csv('./data/sample2.csv', index_col=0)
print(sm2.shape)
sm2.head(2)
# Out:
# (548036, 21)
#         y  msg_length  max_discount  emoji_count  personalized  time_pressure  \
# 500000  0          43           0.0            0             0              0
# 500001  0          43           0.0            0             0              0
#
#         SRCH_EFRT  PRDV_CNT  CAT_CNT  SAMGE_PAGE_CNT  ...  AVG_DEPTH  day_off  \
# 500000          4         1        0               2  ...  41.111111        0
# 500001          4         1        0               2  ...  50.909091        0
#
#         SEX_CD  AVG_SAL_AMT  AGE_30  AGE_50  AGE_60  AGE_1020  WEEKDAY  \
# 500000       1   290.322812       0       1       0         0        4
# 500001       1   290.322812       0       1       0         0        5
#
#         WEEKEND
# 500000        0
# 500001        1
#
# [2 rows x 21 columns]

# %%
df = pd.concat([sm1, sm2])
print(df.shape)
df.head(2)
# Out:
# (1048036, 21)
#    y  msg_length  max_discount  emoji_count  personalized  time_pressure  \
# 0  0          30          32.0            0             0              0
# 1  0          41           0.0            0             0              0
#
#    SRCH_EFRT  PRDV_CNT  CAT_CNT  SAMGE_PAGE_CNT  ...  AVG_DEPTH  day_off  \
# 0          6         2        0               2  ...  24.285714        1
# 1         15         4        0               4  ...  16.666667        0
#
#    SEX_CD  AVG_SAL_AMT  AGE_30  AGE_50  AGE_60  AGE_1020  WEEKDAY  WEEKEND
# 0       1      21490.0       0       0       0         0        4        0
# 1       1      26085.0       0       1       0         0        6        1
#
# [2 rows x 21 columns]

# %%
def determine_age(row):
    if row['AGE_30'] == 1:
        return 30
    elif row['AGE_50'] == 1:
        return 50
    elif row['AGE_60'] == 1:
        return 60
    elif row['AGE_1020'] == 1:
        return 20
    else:
        return 40  # 모든 값이 0이면 40

df['AGE'] = df.apply(determine_age, axis=1)
df.head(2)
# Out:
#    y  msg_length  max_discount  emoji_count  personalized  time_pressure  \
# 0  0          30          32.0            0             0              0
# 1  0          41           0.0            0             0              0
#
#    SRCH_EFRT  PRDV_CNT  CAT_CNT  SAMGE_PAGE_CNT  ...  day_off  SEX_CD  \
# 0          6         2        0               2  ...        1       1
# 1         15         4        0               4  ...        0       1
#
#    AVG_SAL_AMT  AGE_30  AGE_50  AGE_60  AGE_1020  WEEKDAY  WEEKEND  AGE
# 0      21490.0       0       0       0         0        4        0   40
# 1      26085.0       0       1       0         0        6        1   50
#
# [2 rows x 22 columns]

# %%
df_origin = df[['y', 'msg_length', 'max_discount', 'personalized', 'time_pressure', 'AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT',
       'AVG_DEPTH', 'day_off', 'WEEKEND']]

# %% [markdown]
# ### 각 변수 EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family="Malgun Gothic")

import warnings 
warnings.filterwarnings("ignore")


for col in df_origin.columns:
    print('='*50)
    print(f"변수명: {col}")
    print("데이터 유형:", df_origin[col].dtype)

    # 변수에 대한 기초 통계량 출력
    print("기초 통계량:")
    print(df_origin[col].describe())

    if df_origin[col].dtype == 'object' or df_origin[col].nunique() < 10:
        temp = pd.DataFrame(df_origin[col].value_counts()).reset_index()
        print("빈도 분포:")
        print(df_origin[col].value_counts())
        # 막대그래프 그리기
        sns.barplot(x = col,
                    y = 'count',
                    data = temp)
        plt.title(f"{col} 분포(막대그래프)")
        plt.xlabel(col)
        plt.ylabel("빈도수")
        plt.show()
    else:
        # 수치형 변수의 경우 히스토그램과 박스플롯을 통해 분포 및 이상치 확인
        plt.figure(figsize=(12,4))
        plt.subplot(1,2,1)
        df_origin[col].hist(bins=20)
        plt.title(f"{col} 히스토그램")
        plt.xlabel(col)
        plt.ylabel("빈도수")

        plt.subplot(1,2,2)
        df_origin.boxplot(column=col)
        plt.title(f"{col} 박스플롯")

        plt.tight_layout()
        plt.show()
# Out:
# ==================================================
# 변수명: y
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     3.044075e-02
# std      1.717968e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: y, dtype: float64
# 빈도 분포:
# y
# 0    1016133
# 1      31903
# Name: count, dtype: int64
# ==================================================
# 변수명: msg_length
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     1.007307e+02
# std      9.475957e+01
# min      1.700000e+01
# 25%      3.000000e+01
# 50%      4.500000e+01
# 75%      1.770000e+02
# max      3.290000e+02
# Name: msg_length, dtype: float64
# ==================================================
# 변수명: max_discount
# 데이터 유형: float64
# 기초 통계량:
# count    1.048036e+06
# mean     3.318570e+01
# std      2.105396e+01
# min      0.000000e+00
# 25%      2.800000e+01
# 50%      3.333333e+01
# 75%      5.000000e+01
# max      1.000000e+02
# Name: max_discount, dtype: float64
# ==================================================
# 변수명: personalized
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     1.743146e-01
# std      3.793800e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: personalized, dtype: float64
# 빈도 분포:
# personalized
# 0    865348
# 1    182688
# Name: count, dtype: int64
# ==================================================
# 변수명: time_pressure
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     3.266777e-02
# std      1.777656e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: time_pressure, dtype: float64
# 빈도 분포:
# time_pressure
# 0    1013799
# 1      34237
# Name: count, dtype: int64
# ==================================================
# 변수명: AVG_SAL_AMT
# 데이터 유형: float64
# 기초 통계량:
# count    1.048036e+06
# mean     1.468416e+04
# std      9.174287e+03
# min      0.000000e+00
# 25%      8.401250e+03
# 50%      1.421042e+04
# 75%      1.955167e+04
# max      2.635000e+05
# Name: AVG_SAL_AMT, dtype: float64
# ==================================================
# 변수명: SRCH_EFRT
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     1.654643e+01
# std      2.043042e+01
# min      4.000000e+00
# 25%      5.000000e+00
# 50%      9.000000e+00
# 75%      1.900000e+01
# max      4.840000e+02
# Name: SRCH_EFRT, dtype: float64
# ==================================================
# 변수명: CAT_CNT
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     5.489802e-01
# std      8.325031e-01
# min     -1.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      8.000000e+00
# Name: CAT_CNT, dtype: float64
# ==================================================
# 변수명: AVG_DEPTH
# 데이터 유형: float64
# 기초 통계량:
# count    1.048036e+06
# mean     2.615958e+01
# std      1.574562e+01
# min      1.000000e+01
# 25%      1.000000e+01
# 50%      2.166667e+01
# 75%      4.200000e+01
# max      1.000000e+02
# Name: AVG_DEPTH, dtype: float64
# ==================================================
# 변수명: day_off
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     5.677734e-01
# std      4.953857e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: day_off, dtype: float64
# 빈도 분포:
# day_off
# 1    595047
# 0    452989
# Name: count, dtype: int64
# ==================================================
# 변수명: WEEKEND
# 데이터 유형: int64
# 기초 통계량:
# count    1.048036e+06
# mean     2.651188e-01
# std      4.413966e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: WEEKEND, dtype: float64
# 빈도 분포:
# WEEKEND
# 0    770182
# 1    277854
# Name: count, dtype: int64

# %%
def remove_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = 0
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# %%
import statsmodels.api as sm

df_remove = df_origin[df_origin['max_discount'] < 34]
df_remove = remove_outliers(df_remove, ["AVG_SAL_AMT", "SRCH_EFRT", "CAT_CNT", "AVG_DEPTH"])

# 특징 변수와 종속 변수 분리
X = df_remove.drop(columns=['y'])  
y = df_remove['y']

# 상수항 추가
X = sm.add_constant(X)

# 로지스틱 회귀 모델 생성 및 학습
model = sm.Logit(y, X)
result = model.fit()

result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.151690
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               437606
# Model:                          Logit   Df Residuals:                   437595
# Method:                           MLE   Df Model:                           10
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                 0.07270
# Time:                        17:52:18   Log-Likelihood:                -66380.
# converged:                       True   LL-Null:                       -71585.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -3.7734      0.032   -119.777      0.000      -3.835      -3.712
# msg_length        0.0072      0.000     47.861      0.000       0.007       0.008
# max_discount      0.0053      0.001      8.023      0.000       0.004       0.007
# personalized     -1.1759      0.185     -6.372      0.000      -1.538      -0.814
# time_pressure     1.9011      0.033     56.837      0.000       1.836       1.967
# AVG_SAL_AMT    6.444e-06   1.01e-06      6.372      0.000    4.46e-06    8.43e-06
# SRCH_EFRT         0.0065      0.001      5.422      0.000       0.004       0.009
# CAT_CNT          -0.0436      0.015     -2.840      0.005      -0.074      -0.013
# AVG_DEPTH      2.107e-05      0.001      0.038      0.970      -0.001       0.001
# day_off          -0.0401      0.016     -2.470      0.014      -0.072      -0.008
# WEEKEND          -1.9624      0.035    -56.447      0.000      -2.031      -1.894
# =================================================================================
# """

# %% [markdown]
# ### 교호작용항 추가

# %%
df_control = df[['y', 'msg_length', 'max_discount', 'personalized', 'time_pressure', 'AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT',
       'AVG_DEPTH', 'day_off', 'WEEKEND', 'SEX_CD', 'AGE']]


df_control = remove_outliers(df_control, ["AVG_SAL_AMT", "SRCH_EFRT", "CAT_CNT", "AVG_DEPTH"])

dl = ['msg_length', 'max_discount', 'personalized', 'time_pressure']
ml = ['AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT', 'AVG_DEPTH', 'day_off', 'WEEKEND']

df_m = df_control.copy()

for d in dl:
    for m in ml:
       interaction_term = f"{d}_x_{m}"  # 교호작용항 이름 설정
       df_m[interaction_term] = df_m[d] * df_m[m]  # 교호작용항 계산

interaction_term = ['y', 'msg_length', 'max_discount', 'personalized', 'time_pressure', 'AVG_SAL_AMT', 'SRCH_EFRT', 'CAT_CNT',
       'AVG_DEPTH', 'day_off', 'WEEKEND',
       'msg_length_x_SRCH_EFRT', 'msg_length_x_CAT_CNT', 'msg_length_x_AVG_DEPTH', 'max_discount_x_AVG_SAL_AMT', 
       'personalized_x_AVG_SAL_AMT', 'time_pressure_x_SRCH_EFRT', 'time_pressure_x_CAT_CNT', 'time_pressure_x_day_off', 'time_pressure_x_WEEKEND',
       'SEX_CD', 'AGE']

df_m = df_m[interaction_term]
df_m.head(2)
# Out:
#    y  msg_length  max_discount  personalized  time_pressure  AVG_SAL_AMT  \
# 0  0          30          32.0             0              0      21490.0
# 1  0          41           0.0             0              0      26085.0
#
#    SRCH_EFRT  CAT_CNT  AVG_DEPTH  day_off  ...  msg_length_x_CAT_CNT  \
# 0          6        0  24.285714        1  ...                     0
# 1         15        0  16.666667        0  ...                     0
#
#    msg_length_x_AVG_DEPTH  max_discount_x_AVG_SAL_AMT  \
# 0              728.571429                    687680.0
# 1              683.333333                         0.0
#
#    personalized_x_AVG_SAL_AMT  time_pressure_x_SRCH_EFRT  \
# 0                         0.0                          0
# 1                         0.0                          0
#
#    time_pressure_x_CAT_CNT  time_pressure_x_day_off  time_pressure_x_WEEKEND  \
# 0                        0                        0                        0
# 1                        0                        0                        0
#
#    SEX_CD  AGE
# 0       1   40
# 1       1   50
#
# [2 rows x 22 columns]

# %%
# 특징 변수와 종속 변수 분리
X = df_m.drop(columns=['y'])  
y = df_m['y']

# 상수항 추가
X = sm.add_constant(X)

# 로지스틱 회귀 모델 생성 및 학습
model = sm.Logit(y, X)
result = model.fit()

result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.129567
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               878321
# Model:                          Logit   Df Residuals:                   878299
# Method:                           MLE   Df Model:                           21
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                 0.04506
# Time:                        17:53:13   Log-Likelihood:            -1.1380e+05
# converged:                      False   LL-Null:                   -1.1917e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.1473      0.042    -74.068      0.000      -3.231      -3.064
# msg_length                     0.0026      0.000     16.138      0.000       0.002       0.003
# max_discount                  -0.0190      0.001    -29.464      0.000      -0.020      -0.018
# personalized                   0.3680      0.045      8.220      0.000       0.280       0.456
# time_pressure                  1.1842      0.052     22.713      0.000       1.082       1.286
# AVG_SAL_AMT                 6.501e-06   1.25e-06      5.188      0.000    4.05e-06    8.96e-06
# SRCH_EFRT                      0.0111      0.001      7.823      0.000       0.008       0.014
# CAT_CNT                       -0.1024      0.020     -5.239      0.000      -0.141      -0.064
# AVG_DEPTH                      0.0016      0.001      2.450      0.014       0.000       0.003
# day_off                       -0.0162      0.013     -1.221      0.222      -0.042       0.010
# WEEKEND                       -0.8668      0.019    -45.805      0.000      -0.904      -0.830
# msg_length_x_SRCH_EFRT        -0.0001   9.44e-06    -12.799      0.000      -0.000      -0.000
# msg_length_x_CAT_CNT           0.0011      0.000      8.718      0.000       0.001       0.001
# msg_length_x_AVG_DEPTH     -5.169e-06   4.45e-06     -1.161      0.246   -1.39e-05    3.56e-06
# max_discount_x_AVG_SAL_AMT -1.671e-07   4.15e-08     -4.028      0.000   -2.48e-07   -8.58e-08
# personalized_x_AVG_SAL_AMT -8.369e-06   2.37e-06     -3.535      0.000    -1.3e-05   -3.73e-06
# time_pressure_x_SRCH_EFRT     -0.0052      0.003     -1.586      0.113      -0.012       0.001
# time_pressure_x_CAT_CNT       -0.0578      0.047     -1.234      0.217      -0.150       0.034
# time_pressure_x_day_off        0.0904      0.049      1.834      0.067      -0.006       0.187
# time_pressure_x_WEEKEND      -15.2623    101.226     -0.151      0.880    -213.662     183.137
# SEX_CD                        -0.0220      0.021     -1.046      0.295      -0.063       0.019
# AGE                            0.0006      0.001      0.994      0.320      -0.001       0.002
# ==============================================================================================
# """

# %% [markdown]
# ### 모델 평가

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

logit = LogisticRegression()
logit.fit(X,y)
X.head(2)
# Out:
#    const  msg_length  max_discount  personalized  time_pressure  AVG_SAL_AMT  \
# 0    1.0          30          32.0             0              0      21490.0
# 1    1.0          41           0.0             0              0      26085.0
#
#    SRCH_EFRT  CAT_CNT  AVG_DEPTH  day_off  ...  msg_length_x_CAT_CNT  \
# 0          6        0  24.285714        1  ...                     0
# 1         15        0  16.666667        0  ...                     0
#
#    msg_length_x_AVG_DEPTH  max_discount_x_AVG_SAL_AMT  \
# 0              728.571429                    687680.0
# 1              683.333333                         0.0
#
#    personalized_x_AVG_SAL_AMT  time_pressure_x_SRCH_EFRT  \
# 0                         0.0                          0
# 1                         0.0                          0
#
#    time_pressure_x_CAT_CNT  time_pressure_x_day_off  time_pressure_x_WEEKEND  \
# 0                        0                        0                        0
# 1                        0                        0                        0
#
#    SEX_CD  AGE
# 0       1   40
# 1       1   50
#
# [2 rows x 22 columns]

# %%
predict = logit.predict(X)

# 분류모델 평가
print('accuracy score:', accuracy_score(y, predict))
print('f1_score score:', f1_score(y, predict))
print('recall score:', recall_score(y, predict))
print('precision score', precision_score(y, predict))
# Out:
# accuracy score: 0.9695213936590381
# f1_score score: 0.0006719426608929372
# recall score: 0.00033851130251626735
# precision score 0.04477611940298507

# %% [markdown]
# ### 변수 확인

# %%
import numpy as np

# 상관 계수 행렬 계산
corr_matrix = df_m.corr().abs()

# 상관 계수가 높은 변수 찾기
high_corr_var = np.where(corr_matrix > 0.7)
high_corr_var = [(corr_matrix.index[x], corr_matrix.columns[y]) for x, y in zip(*high_corr_var) if x != y and x < y]

# 높은 상관 관계를 갖는 변수 출력
print("상관 관계가 높은 변수들:", high_corr_var)
# Out:
# 상관 관계가 높은 변수들: [('msg_length', 'personalized'), ('msg_length', 'msg_length_x_AVG_DEPTH'), ('msg_length', 'personalized_x_AVG_SAL_AMT'), ('personalized', 'personalized_x_AVG_SAL_AMT'), ('time_pressure', 'time_pressure_x_SRCH_EFRT'), ('time_pressure', 'time_pressure_x_day_off'), ('msg_length_x_SRCH_EFRT', 'msg_length_x_AVG_DEPTH'), ('time_pressure_x_SRCH_EFRT', 'time_pressure_x_CAT_CNT')]

# %%
# 다중공선성
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

df_X = df_control.drop(columns=['y'])

def calculate_vif(df):
    df_const = add_constant(df)
    vif = pd.DataFrame()
    vif["feature"] = df_const.columns
    vif["VIF"] = [variance_inflation_factor(df_const.values, i) for i in range(df_const.shape[1])]
    return vif

vif_df = calculate_vif(df_X)
print(vif_df)
# Out:
#           feature        VIF
# 0           const  38.067117
# 1      msg_length   2.934061
# 2    max_discount   1.072422
# 3    personalized   3.018863
# 4   time_pressure   1.021196
# 5     AVG_SAL_AMT   1.067921
# 6       SRCH_EFRT   1.446219
# 7         CAT_CNT   1.333904
# 8       AVG_DEPTH   1.187585
# 9         day_off   1.014740
# 10        WEEKEND   1.001436
# 11         SEX_CD   1.007434
# 12            AGE   1.016433

# %%
df_X.corr()
# Out:
#                msg_length  max_discount  personalized  time_pressure  \
# msg_length       1.000000     -0.007724      0.800434      -0.102674
# max_discount    -0.007724      1.000000      0.140215      -0.082772
# personalized     0.800434      0.140215      1.000000      -0.083055
# time_pressure   -0.102674     -0.082772     -0.083055       1.000000
# AVG_SAL_AMT      0.081200      0.045950      0.138851       0.037832
# SRCH_EFRT        0.027298      0.029845      0.058261       0.012487
# CAT_CNT          0.019955      0.031590      0.055048       0.006562
# AVG_DEPTH        0.017135      0.033105      0.065174       0.019583
# day_off          0.000748     -0.013236     -0.024322      -0.008860
# WEEKEND         -0.015382     -0.008534     -0.014938       0.011800
# SEX_CD          -0.017096      0.001885     -0.021648      -0.002328
# AGE             -0.009615      0.005386     -0.006041       0.012062
#
#                AVG_SAL_AMT  SRCH_EFRT   CAT_CNT  AVG_DEPTH   day_off  \
# msg_length        0.081200   0.027298  0.019955   0.017135  0.000748
# max_discount      0.045950   0.029845  0.031590   0.033105 -0.013236
# personalized      0.138851   0.058261  0.055048   0.065174 -0.024322
# time_pressure     0.037832   0.012487  0.006562   0.019583 -0.008860
# AVG_SAL_AMT       1.000000   0.107482  0.138906   0.144342 -0.079280
# SRCH_EFRT         0.107482   1.000000  0.484979   0.374232 -0.049074
# CAT_CNT           0.138906   0.484979  1.000000   0.232864 -0.089372
# AVG_DEPTH         0.144342   0.374232  0.232864   1.000000 -0.050290
# day_off          -0.079280  -0.049074 -0.089372  -0.050290  1.000000
# WEEKEND          -0.008351  -0.014554  0.009231   0.001511 -0.018349
# SEX_CD           -0.028265  -0.009488  0.012100   0.006637  0.003088
# AGE               0.084345  -0.004123  0.036086  -0.026377 -0.025232
#
#                 WEEKEND    SEX_CD       AGE
# msg_length    -0.015382 -0.017096 -0.009615
# max_discount  -0.008534  0.001885  0.005386
# personalized  -0.014938 -0.021648 -0.006041
# time_pressure  0.011800 -0.002328  0.012062
# AVG_SAL_AMT   -0.008351 -0.028265  0.084345
# SRCH_EFRT     -0.014554 -0.009488 -0.004123
# CAT_CNT        0.009231  0.012100  0.036086
# AVG_DEPTH      0.001511  0.006637 -0.026377
# day_off       -0.018349  0.003088 -0.025232
# WEEKEND        1.000000 -0.002910  0.004057
# SEX_CD        -0.002910  1.000000  0.071930
# AGE            0.004057  0.071930  1.000000

# %% [markdown]
# ### 독립성

# %%
from statsmodels.stats.stattools import durbin_watson

model2 = sm.GLM(y, X, family=sm.families.Binomial())
result2 = model2.fit()

residuals = result2.resid_deviance
dw_stat = durbin_watson(residuals)

print("Durbin-Watson 통계량:", dw_stat)
# Out:
# Durbin-Watson 통계량: 1.3865141408528876

# %% [markdown]
# ## 추가분석

# %% [markdown]
# ### 샘플링 후 분석

# %%
df_0 = df_m[df_m['y'] == 0]
df_1 = df_m[df_m['y'] == 1]

print(df_0.shape)
print(df_1.shape)
# Out:
# (851734, 22)
# (26587, 22)

# %%
df_0 = df_0.sample(n=16907, random_state=21)

df_sample = pd.concat([df_0, df_1], ignore_index=True)

# 특징 변수와 종속 변수 분리
X_sample = df_sample.drop(columns=['y'])  
y_sample = df_sample['y']

# 상수항 추가
X_sample = sm.add_constant(X_sample)

# 로지스틱 회귀 모델 생성 및 학습
model = sm.Logit(y_sample, X_sample)
result = model.fit()

result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.612221
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                43494
# Model:                          Logit   Df Residuals:                    43472
# Method:                           MLE   Df Model:                           21
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                 0.08374
# Time:                        17:53:25   Log-Likelihood:                -26628.
# converged:                      False   LL-Null:                       -29061.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.7775      0.073     10.692      0.000       0.635       0.920
# msg_length                     0.0035      0.000     12.575      0.000       0.003       0.004
# max_discount                  -0.0206      0.001    -18.928      0.000      -0.023      -0.018
# personalized                   0.6557      0.079      8.289      0.000       0.501       0.811
# time_pressure                  0.9873      0.127      7.767      0.000       0.738       1.236
# AVG_SAL_AMT                   6.1e-06   2.45e-06      2.495      0.013    1.31e-06    1.09e-05
# SRCH_EFRT                      0.0117      0.002      5.144      0.000       0.007       0.016
# CAT_CNT                       -0.1011      0.030     -3.328      0.001      -0.161      -0.042
# AVG_DEPTH                      0.0011      0.001      1.010      0.312      -0.001       0.003
# day_off                       -0.0173      0.022     -0.803      0.422      -0.060       0.025
# WEEKEND                       -1.0942      0.028    -38.786      0.000      -1.150      -1.039
# msg_length_x_SRCH_EFRT        -0.0001   1.53e-05     -9.119      0.000      -0.000      -0.000
# msg_length_x_CAT_CNT           0.0010      0.000      4.754      0.000       0.001       0.001
# msg_length_x_AVG_DEPTH      3.673e-07   7.64e-06      0.048      0.962   -1.46e-05    1.53e-05
# max_discount_x_AVG_SAL_AMT -1.559e-07   7.07e-08     -2.206      0.027   -2.94e-07   -1.74e-08
# personalized_x_AVG_SAL_AMT -1.562e-05   3.97e-06     -3.937      0.000   -2.34e-05   -7.84e-06
# time_pressure_x_SRCH_EFRT      0.0113      0.008      1.381      0.167      -0.005       0.027
# time_pressure_x_CAT_CNT       -0.2606      0.107     -2.437      0.015      -0.470      -0.051
# time_pressure_x_day_off        0.0215      0.119      0.181      0.857      -0.211       0.254
# time_pressure_x_WEEKEND      -24.4274   1.14e+04     -0.002      0.998   -2.24e+04    2.24e+04
# SEX_CD                        -0.0223      0.035     -0.641      0.522      -0.091       0.046
# AGE                            0.0002      0.001      0.221      0.825      -0.002       0.002
# ==============================================================================================
# """

# %%
logit = LogisticRegression()
logit.fit(X_sample,y_sample)

predict = logit.predict(X)

# 분류모델 평가
print('accuracy score:', accuracy_score(y, predict))
print('f1_score score:', f1_score(y, predict))
print('recall score:', recall_score(y, predict))
print('precision score', precision_score(y, predict))
# Out:
# accuracy score: 0.22131771869282416
# f1_score score: 0.0659090319329246
# recall score: 0.9075488020461128
# precision score 0.0341962347152227

# %%
from scipy.stats import chi2

pred_prob = result.predict(X)

pred_df = pd.DataFrame({
    'y' : y,
    'pred_prob' : pred_prob
})

pred_df['decile'] = pd.qcut(pred_df['pred_prob'], 10, labels=False)

hl_data = pred_df.groupby('decile').apply(
    lambda group: pd.Series({
        'observed_positivies': group['y'].sum(),
        'observed_negatives': group['y'].count() - group['y'].sum(),
        'expected_positivies': group['pred_prob'].sum(),
        'expected_negatives': group['pred_prob'].count() - group['pred_prob'].sum()
    })
)

hl_data['chi2'] = (
    (hl_data['observed_positivies'] - hl_data['expected_positivies'])**2 / hl_data['expected_positivies'] + 
    (hl_data['observed_negatives'] - hl_data['expected_positivies'])**2 / hl_data['expected_negatives']
)

hl_stat = hl_data['chi2'].sum()
dfree = 10-2
p_value = 1 - chi2.cdf(hl_stat, dfree)

print("Hosmer-Lemeshow ch2 통계량 : ", hl_stat)
print("자유도 : ", dfree)
print("p-value : ", p_value)
# Out:
# Hosmer-Lemeshow ch2 통계량 :  777376.5561303762
# 자유도 :  8
# p-value :  0.0

# %%
def geometric_mean(data):
    data = np.array(data)
    if np.any(data <= 0):
        raise ValueError
    return np.exp(np.mean(np.log(data)))

g_mean = geometric_mean(pred_prob)
print("예측 확률의 기하 평균:", g_mean)
# Out:
# 예측 확률의 기하 평균: 0.417879572993457

# %% [markdown]
# ### ROC-AUC

# %%
from sklearn.metrics import roc_auc_score, roc_curve
roc_auc = roc_auc_score(y, pred_prob)
print("ROC-AUC:", roc_auc)

fpr, tpr, thresholds = roc_curve(y, pred_prob)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC-AUC: 0.6627923066423742
